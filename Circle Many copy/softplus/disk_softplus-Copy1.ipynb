# %%
import copy
import numpy as np
import time
from neural_network import NNTrain, get_p
import nn_functions as nn
from nn_functions import relative_err_without_points as rel_err
from plots import plot_fun, plot_iteration, animate_p

# %%
# %matplotlib notebook
# %matplotlib notebook

# %%
a = NNTrain(dx_r=0.3, dx_th=0.06, bx=0.01, hidden_nodes=10, alpha=1e-5, batch_size=32, bc=1)

# %%
p=[]
p.append(copy.deepcopy(get_p(a)))
a.train(100)

# %%
bc_multiplier = 5
thresh = 1e-5

for i in range(100000):
    p.append(copy.deepcopy(get_p(a)))
    if a.alpha < 1e-9  or a.bc > 100000:
        break
    if np.abs(np.mean([s-t for s, t in zip(a.cost_rate[-101:], a.cost_rate[-100:])])) < thresh:
        a.bc *= bc_multiplier
        a.alpha /= bc_multiplier
    a.train(100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-4b058374ceef> in <module>
#       9         a.bc *= bc_multiplier
#      10         a.alpha /= bc_multiplier
# ---> 11     a.train(100)
#
# ~\OneDrive\Documents\Level 3\Final Year Dissertation\NN code\FPY\Circle Many copy\softplus\neural_network.py in train(self, itr)
#     101             for mini_point, mini_boundary in zip(mini_batch_points, mini_batch_boundary):
#     102
# --> 103                 g_w0 = nn.dE_dwj(mini_point, mini_boundary, self.p00, self.p01, self.p1, self.p2, 0, self.bc)
#     104                 g_w1 = nn.dE_dwj(mini_point, mini_boundary, self.p00, self.p01, self.p1, self.p2, 1, self.bc)
#     105                 g_u = nn.dE_du(mini_point, mini_boundary, self.p00, self.p01, self.p1, self.p2, self.bc)
#
# ~\OneDrive\Documents\Level 3\Final Year Dissertation\NN code\FPY\Circle Many copy\softplus\nn_functions.py in dE_dwj(points, boundary_points, p00, p01, p1, p2, j, BC)
#     207         t1[i] = 2 * error_term1(pnt[0],pnt[1],p00, p01, p1, p2) * (
#     208                 d_dwj_dN2_dxk2(pnt[0],pnt[1],p00, p01, p1, p2,j,0) +
# --> 209                 d_dwj_dN2_dxk2(pnt[0],pnt[1],p00, p01, p1, p2,j,1))
#     210
#     211     for i, pnt in enumerate(boundary_points):
#
# KeyboardInterrupt:

# %%
a.bc *= bc_multiplier
a.alpha /= bc_multiplier

# %%
print('alpha:', a.alpha)
print('BC:', a.bc)
print('relative error:', rel_err(a.p00, a.p01, a.p1, a.p2, dx_r=0.01, dx_th=0.005))
print('number of iterations:', len(a.cost_rate))
# Out:
# alpha: 4.000000000000001e-07
# BC: 25
# relative error: 0.017040668323011175
# number of iterations: 140184

# %%
plot_iteration(a.cost_rate, min_it=35000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_iteration(a.rel_err, min_it=35000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_fun(nn.N, p00=a.p00, p01=a.p01, p1=a.p1, p2=a.p2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_fun(nn.psi_a)

# %%
rel_err_for_p = []

# %%
for i in range(len(rel_err_for_p), len(p)):
    rel_err_for_p.append(rel_err(p[i][0][0], p[i][0][1], p[i][1], p[i][2], dx_r=0.013, dx_th=0.008))

# %%
rel_err_for_p = np.array(rel_err_for_p)
print(np.where(rel_err_for_p==np.amin(rel_err_for_p))[0][0], np.amin(rel_err_for_p))
# Out:
# 844 0.00907268238279889

# %%
i=844
rel_err(p[i][0][0], p[i][0][1], p[i][1], p[i][2], dx_r=0.01, dx_th=0.005)
# Out:
# 0.00907586147919677

# %% [markdown]
# ### Load parameters

# %%
name_str = '20200817-2017_eq1_1_v6'

par = np.load('output/' + name_str + '_nn_params.npz', allow_pickle=True)['arr_0']
a.p00 = par[0][0]
a.p01 = par[0][1]
a.p1 = par[1]
a.p2 = par[2]
a.cost_rate = list(np.load('output/' + name_str + '_cost_rate.npz')['arr_0'])
a.rel_err = list(np.load('output/' + name_str + '_rel_err.npz')['arr_0'])
a.m_t = np.load('output/' + name_str + '_momentum.npz')['arr_0']

# %%
output_name = 'disk_soft_1_v1'
timestr = time.strftime("%Y%m%d-%H%M")

a.save_result(output_name)

np.savez('output/'+ timestr + '_' + output_name +'_p_list.npz', p)
